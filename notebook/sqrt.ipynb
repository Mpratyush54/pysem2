# %%
import math
input_value = int(input("Enter a non-negative integer: "))
x = math.factorial(input_value)
print()

# %%
import math
import random
import time
for i in range(10):
    print(f"Print 10 random numbers: {random.randint(1, 100)}")
    time.sleep(1)
# Out:
# Print 10 random numbers: 100
# Print 10 random numbers: 19
# Print 10 random numbers: 86
# Print 10 random numbers: 47
# Print 10 random numbers: 89
# Print 10 random numbers: 23
# Print 10 random numbers: 94
# Print 10 random numbers: 39
# Print 10 random numbers: 41
# Print 10 random numbers: 53
