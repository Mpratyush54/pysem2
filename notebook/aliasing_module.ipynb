# %%
import random
import time
import math

print("Print pi value:", math.pi)
print("Print cosine ", math.cos(math.pi))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import random
#       2 import time
# ----> 4 print("Print pi value:", math.pi)
#       5 print("Print cosine ", math.cos(math.pi))
#
# NameError: name 'math' is not defined
